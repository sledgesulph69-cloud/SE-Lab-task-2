# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#given a 4Xn board and tiles of size 4X1, count the number of ways to tile the given board using the 4X1 tiles. A tile can be placed horizontally or vertically
'''def tiling(n):
    if n <=3:
        return 1
    else:
        res = tiling(n-1)+tiling(n-4)
    return res'''
dih = {0: 1,
       1: 1,
       2: 1}
def tiling_w_dp(n):
    if n<0:
        return 0
    if n not in dih:
        dih[n] = tiling_w_dp(n-1)+tiling_w_dp(n-4)
    return dih[n]
n = 101
print(n, tiling_w_dp(n))
# Out:
# 101 74986666876571

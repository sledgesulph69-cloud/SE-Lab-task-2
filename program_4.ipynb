# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def coupon_collector(n):
    sum_series = 0
    for i in range(1, n+1):
        sum_series += 1/i
    result = n*sum_series
    return result

print(coupon_collector(6))
# Out:
# 14.7

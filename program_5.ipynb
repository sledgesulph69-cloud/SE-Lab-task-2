# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def display(str1):
    if len(str1) == 0:
        return
    print(str1[0])
    display(str1[1:])
def rev_display(str1):
    if len(str1) == 0:
        return
    rev_display(str1[1:])
    print(str1[0])
str1 = "Hello"

length = len(str1)
display(str1)
rev_display(str1)
# Out:
# H
# e
# l
# l
# o
# o
# l
# l
# e
# H

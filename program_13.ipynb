# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        left, right = 0, len(s) - 1

        while left < right:
            # move left to next alphanumeric
            while left < right and not s[left].isalnum():
                left += 1
            # move right to previous alphanumeric
            while left < right and not s[right].isalnum():
                right -= 1

            if s[left].lower() != s[right].lower():
                return False

            left += 1
            right -= 1

        return True

print(Solution().isPalindrome("race a car"))          # False
print(Solution().isPalindrome("A man, a plan..."))    # True
# Out:
# False
# False

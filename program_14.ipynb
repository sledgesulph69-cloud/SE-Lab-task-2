# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def power(x,y,p):
    if y == 1:
        return x
    res = power(x,y//2, p)
    res = (res%p)*(res%p)
    if y%2 == 1:
        res = (res%p)*x
    return res
print(power(2,10, 5))
# Out:
# 4

# %% [markdown]
# <a href="https://colab.research.google.com/github/sledgesulph69-cloud/SE-Lab-task-2/blob/main/program_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Given n friends, each one can remain single or can be paired up with some other friend can be pairedd only once.
Findo out the total number of ways in which friends can remain single or can be paired up'''

'''def pair_without_dp(n):
    if n<=2:
        return n
    return pair_without_dp(n-1)+(n-1)*pair_without_dp(n-2)
for n in range(1,51):
    print(n, pair_without_dp(n))'''
dp = {1: 1,
      2: 2}
def pair_with_dp(n):
    if n not in dp:
        dp[n] = pair_with_dp(n-1)+(n-1)*pair_with_dp(n-2)
    return dp[n]


for n in range(1,11):
    print(n, pair_with_dp(n))
# Out:
# 1 1
# 2 2
# 3 4
# 4 10
# 5 26
# 6 76
# 7 232
# 8 764
# 9 2620
# 10 9496
